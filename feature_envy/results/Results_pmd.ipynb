# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
import pickle

file_path = './results.pkl'
with open(file_path, "rb") as fh:
  results_df = pickle.load(fh)

results_df.columns = ['dataset', 'random_seed', 'train_f1_micro', 'train_f1_macro', 'train_accuracy', 'classification_report']
results_df.head()
# Out:
#                   dataset random_seed  train_f1_micro  train_f1_macro  \
# 0  metrics_pmd_merged.pkl           0        0.974776        0.836088
# 1  metrics_pmd_merged.pkl           1        0.971413        0.821401
# 2  metrics_pmd_merged.pkl           2        0.977018        0.846540
# 3  metrics_pmd_merged.pkl           3        0.971973        0.823771
# 4  metrics_pmd_merged.pkl           4        0.977578        0.849242
#
#    train_accuracy                              classification_report
# 0        0.974776                precision    recall  f1-score   ...
# 1        0.971413                precision    recall  f1-score   ...
# 2        0.977018                precision    recall  f1-score   ...
# 3        0.971973                precision    recall  f1-score   ...
# 4        0.977578                precision    recall  f1-score   ...

# %%
# parse dataset name
results_df.dataset = [x.split('/')[-1].split('.')[0] for x in results_df.dataset]
results_df.classification_report = [x.split() for x in results_df.classification_report]
results_df.head()
# Out:
#               dataset random_seed  train_f1_micro  train_f1_macro  \
# 0  metrics_pmd_merged           0        0.974776        0.836088
# 1  metrics_pmd_merged           1        0.971413        0.821401
# 2  metrics_pmd_merged           2        0.977018        0.846540
# 3  metrics_pmd_merged           3        0.971973        0.823771
# 4  metrics_pmd_merged           4        0.977578        0.849242
#
#    train_accuracy                              classification_report
# 0        0.974776  [precision, recall, f1-score, support, 0, 0.98...
# 1        0.971413  [precision, recall, f1-score, support, 0, 0.98...
# 2        0.977018  [precision, recall, f1-score, support, 0, 0.98...
# 3        0.971973  [precision, recall, f1-score, support, 0, 0.98...
# 4        0.977578  [precision, recall, f1-score, support, 0, 0.97...

# %%
# parse classification report
results_df['precision_0'] = [float(x[5]) for x in results_df.classification_report]
results_df['recall_0'] = [float(x[6]) for x in results_df.classification_report]
results_df['f1_score_0'] = [float(x[7]) for x in results_df.classification_report]

results_df['precision_1'] = [float(x[10]) for x in results_df.classification_report]
results_df['recall_1'] = [float(x[11]) for x in results_df.classification_report]
results_df['f1_score_1'] = [float(x[12]) for x in results_df.classification_report]

results_df['accuracy'] = [float(x[15]) for x in results_df.classification_report]

results_df['precision_macro_avg'] = [float(x[19]) for x in results_df.classification_report]
results_df['recall_macro_avg'] = [float(x[20]) for x in results_df.classification_report]
results_df['f1_score_macro_avg'] = [float(x[21]) for x in results_df.classification_report]

results_df['precision_weighted_avg'] = [float(x[25]) for x in results_df.classification_report]
results_df['recall_weighted_avg'] = [float(x[26]) for x in results_df.classification_report]
results_df['f1_score_weighted_avg'] = [float(x[27]) for x in results_df.classification_report]

results_df.drop(columns=['classification_report'], inplace=True)

results_df.head()
# Out:
#               dataset random_seed  train_f1_micro  train_f1_macro  \
# 0  metrics_pmd_merged           0        0.974776        0.836088
# 1  metrics_pmd_merged           1        0.971413        0.821401
# 2  metrics_pmd_merged           2        0.977018        0.846540
# 3  metrics_pmd_merged           3        0.971973        0.823771
# 4  metrics_pmd_merged           4        0.977578        0.849242
#
#    train_accuracy  precision_0  recall_0  f1_score_0  precision_1  recall_1  \
# 0        0.974776         0.98      0.96        0.97         0.22      0.38
# 1        0.971413         0.98      0.96        0.97         0.24      0.38
# 2        0.977018         0.98      0.95        0.96         0.15      0.31
# 3        0.971973         0.98      0.96        0.97         0.20      0.31
# 4        0.977578         0.97      0.96        0.97         0.06      0.08
#
#    f1_score_1  accuracy  precision_macro_avg  recall_macro_avg  \
# 0        0.28      0.94                 0.60              0.67
# 1        0.29      0.95                 0.61              0.67
# 2        0.20      0.93                 0.56              0.63
# 3        0.24      0.94                 0.59              0.64
# 4        0.07      0.94                 0.52              0.52
#
#    f1_score_macro_avg  precision_weighted_avg  recall_weighted_avg  \
# 0                0.62                    0.96                 0.94
# 1                0.63                    0.96                 0.95
# 2                0.58                    0.95                 0.93
# 3                0.61                    0.96                 0.94
# 4                0.52                    0.95                 0.94
#
#    f1_score_weighted_avg
# 0                   0.95
# 1                   0.95
# 2                   0.94
# 3                   0.95
# 4                   0.94

# %%
results_df.describe()
# Out:
#        train_f1_micro  train_f1_macro  train_accuracy  precision_0   recall_0  \
# count       51.000000       51.000000       51.000000    51.000000  51.000000
# mean         0.975051        0.838775        0.975051     0.978039   0.964706
# std          0.003101        0.014445        0.003101     0.004481   0.008568
# min          0.968610        0.809980        0.968610     0.970000   0.940000
# 25%          0.973094        0.828603        0.973094     0.980000   0.960000
# 50%          0.974776        0.838254        0.974776     0.980000   0.960000
# 75%          0.977298        0.848935        0.977298     0.980000   0.970000
# max          0.984305        0.884821        0.984305     0.990000   0.980000
#
#        f1_score_0  precision_1   recall_1  f1_score_1   accuracy  \
# count   51.000000    51.000000  51.000000   51.000000  51.000000
# mean     0.971569     0.194118   0.285686    0.228627   0.944118
# std      0.005049     0.062616   0.101710    0.073185   0.009834
# min      0.960000     0.060000   0.080000    0.060000   0.920000
# 25%      0.970000     0.155000   0.230000    0.185000   0.940000
# 50%      0.970000     0.200000   0.310000    0.240000   0.940000
# 75%      0.970000     0.240000   0.380000    0.275000   0.950000
# max      0.980000     0.320000   0.540000    0.400000   0.960000
#
#        precision_macro_avg  recall_macro_avg  f1_score_macro_avg  \
# count            51.000000         51.000000           51.000000
# mean              0.585686          0.625294            0.599804
# std               0.032265          0.050054            0.037496
# min               0.510000          0.520000            0.520000
# 25%               0.565000          0.595000            0.570000
# 50%               0.590000          0.630000            0.610000
# 75%               0.610000          0.670000            0.620000
# max               0.650000          0.750000            0.690000
#
#        precision_weighted_avg  recall_weighted_avg  f1_score_weighted_avg
# count               51.000000            51.000000              51.000000
# mean                 0.956863             0.944118               0.949804
# std                  0.005095             0.009834               0.006478
# min                  0.950000             0.920000               0.940000
# 25%                  0.950000             0.940000               0.950000
# 50%                  0.960000             0.940000               0.950000
# 75%                  0.960000             0.950000               0.950000
# max                  0.970000             0.960000               0.960000

# %%
columns = ['f1_score_1', 'precision_1', 'recall_1', 'accuracy']

# %%
results_df.groupby(by=['dataset'])[columns].describe(percentiles=[])
# Out:
#                    f1_score_1                                       \
#                         count      mean       std   min   50%  max
# dataset
# metrics_pmd_merged       51.0  0.228627  0.073185  0.06  0.24  0.4
#
#                    precision_1                                      recall_1  \
#                          count      mean       std   min  50%   max    count
# dataset
# metrics_pmd_merged        51.0  0.194118  0.062616  0.06  0.2  0.32     51.0
#
#                                                         accuracy            \
#                         mean      std   min   50%   max    count      mean
# dataset
# metrics_pmd_merged  0.285686  0.10171  0.08  0.31  0.54     51.0  0.944118
#
#
#                          std   min   50%   max
# dataset
# metrics_pmd_merged  0.009834  0.92  0.94  0.96

# %%
results_df.groupby(by=['dataset']).describe(percentiles=[])
# Out:
#                    train_f1_micro                                         \
#                             count      mean       std      min       50%
# dataset
# metrics_pmd_merged           51.0  0.975051  0.003101  0.96861  0.974776
#
#                              train_f1_macro                               \
#                          max          count      mean       std      min
# dataset
# metrics_pmd_merged  0.984305           51.0  0.838775  0.014445  0.80998
#
#                                        train_accuracy                      \
#                          50%       max          count      mean       std
# dataset
# metrics_pmd_merged  0.838254  0.884821           51.0  0.975051  0.003101
#
#                                                 precision_0            \
#                         min       50%       max       count      mean
# dataset
# metrics_pmd_merged  0.96861  0.974776  0.984305        51.0  0.978039
#
#                                                recall_0                      \
#                          std   min   50%   max    count      mean       std
# dataset
# metrics_pmd_merged  0.004481  0.97  0.98  0.99     51.0  0.964706  0.008568
#
#                                      f1_score_0                            \
#                      min   50%   max      count      mean       std   min
# dataset
# metrics_pmd_merged  0.94  0.96  0.98       51.0  0.971569  0.005049  0.96
#
#                                precision_1                                 \
#                      50%   max       count      mean       std   min  50%
# dataset
# metrics_pmd_merged  0.97  0.98        51.0  0.194118  0.062616  0.06  0.2
#
#                          recall_1                                       \
#                      max    count      mean      std   min   50%   max
# dataset
# metrics_pmd_merged  0.32     51.0  0.285686  0.10171  0.08  0.31  0.54
#
#                    f1_score_1                                      accuracy  \
#                         count      mean       std   min   50%  max    count
# dataset
# metrics_pmd_merged       51.0  0.228627  0.073185  0.06  0.24  0.4     51.0
#
#                                                          precision_macro_avg  \
#                         mean       std   min   50%   max               count
# dataset
# metrics_pmd_merged  0.944118  0.009834  0.92  0.94  0.96                51.0
#
#                                                          recall_macro_avg  \
#                         mean       std   min   50%   max            count
# dataset
# metrics_pmd_merged  0.585686  0.032265  0.51  0.59  0.65             51.0
#
#                                                          f1_score_macro_avg  \
#                         mean       std   min   50%   max              count
# dataset
# metrics_pmd_merged  0.625294  0.050054  0.52  0.63  0.75               51.0
#
#                                                           \
#                         mean       std   min   50%   max
# dataset
# metrics_pmd_merged  0.599804  0.037496  0.52  0.61  0.69
#
#                    precision_weighted_avg                                  \
#                                     count      mean       std   min   50%
# dataset
# metrics_pmd_merged                   51.0  0.956863  0.005095  0.95  0.96
#
#                          recall_weighted_avg                                  \
#                      max               count      mean       std   min   50%
# dataset
# metrics_pmd_merged  0.97                51.0  0.944118  0.009834  0.92  0.94
#
#                          f1_score_weighted_avg                            \
#                      max                 count      mean       std   min
# dataset
# metrics_pmd_merged  0.96                  51.0  0.949804  0.006478  0.94
#
#
#                      50%   max
# dataset
# metrics_pmd_merged  0.95  0.96
